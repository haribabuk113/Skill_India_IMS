# %% [markdown]
# # Reading data from JSON

# %%
import json

fd = open("records.json",'r')
r = fd.read()
fd.close()

record = json.loads(r)

# %%
record
# Out:
# {'1': {'Name': 'Ghee',
#   'Color': 'Yellow',
#   'Brand': 'Diary',
#   'Price': 50,
#   'Weight': 100,
#   'Quantity': 100},
#  '2': {'Name': 'Wheat',
#   'Color': 'White',
#   'Brand': 'Asarvad',
#   'Price': 67,
#   'Weight': 200,
#   'Quantity': 100},
#  '3': {'Name': 'Rice',
#   'Color': 'White',
#   'Brand': 'Fast',
#   'Price': 120,
#   'Weight': 230,
#   'Quantity': 100},
#  '4': {'Name': 'Biscuit',
#   'Color': 'Brown',
#   'Brand': 'Britania',
#   'Price': 20,
#   'Weight': 230,
#   'Quantity': 100},
#  '5': {'Name': 'Milk',
#   'Color': 'White',
#   'Brand': 'Diary',
#   'Price': 25,
#   'Weight': 10,
#   'Quantity': 100},
#  '6': {'Name': 'Egg',
#   'Color': 'White',
#   'Brand': 'Grow',
#   'Price': 15,
#   'Weight': 230,
#   'Quantity': 100},
#  '7': {'Name': 'Chocolate',
#   'Color': 'Black',
#   'Brand': 'Dairy',
#   'Price': 235,
#   'Weight': 230,
#   'Quantity': 100},
#  '8': {'Name': 'Drink',
#   'Color': 'Green',
#   'Brand': 'Pepsi',
#   'Price': 200,
#   'Weight': 230,
#   'Quantity': 100},
#  '9': {'Name': 'Jaggery',
#   'Color': 'Brown',
#   'Brand': 'Sweet',
#   'Price': 50,
#   'Weight': 20,
#   'Quantity': 100},
#  '10': {'Name': 'Salt',
#   'Color': 'White',
#   'Brand': 'Indian',
#   'Price': 20,
#   'Weight': 20,
#   'Quantity': 100},
#  '11': {'Name': 'Sugar',
#   'Color': 'White',
#   'Brand': 'Indian',
#   'Price': 10,
#   'Weight': 20,
#   'Quantity': 100},
#  '12': {'Name': 'Noodles',
#   'Color': 'White',
#   'Brand': 'Dragon',
#   'Price': 30,
#   'Weight': 20,
#   'Quantity': 100},
#  '13': {'Name': 'Jam',
#   'Color': 'Red',
#   'Brand': 'Kissan',
#   'Price': 50,
#   'Weight': 60,
#   'Quantity': 100},
#  '14': {'Name': 'Honey',
#   'Color': 'Red',
#   'Brand': 'Kissan',
#   'Price': 10,
#   'Weight': 10,
#   'Quantity': 100},
#  '15': {'Name': 'Tea',
#   'Color': 'Brown',
#   'Brand': 'Kashmir',
#   'Price': 20,
#   'Weight': 50,
#   'Quantity': 100},
#  '16': {'Name': 'Coffee',
#   'Color': 'Brown',
#   'Brand': 'Kashmir',
#   'Price': 20,
#   'Weight': 50,
#   'Quantity': 100},
#  '17': {'Name': 'Ketchup',
#   'Color': 'Red',
#   'Brand': 'Red',
#   'Price': 10,
#   'Weight': 40,
#   'Quantity': 100},
#  '18': {'Name': 'Pickle',
#   'Color': 'Red',
#   'Brand': 'Red',
#   'Price': 50,
#   'Weight': 30,
#   'Quantity': 100},
#  '19': {'Name': 'Shampoo',
#   'Color': 'Blue',
#   'Brand': 'Honey',
#   'Price': 60,
#   'Weight': 40,
#   'Quantity': 100},
#  '20': {'Name': 'Brush',
#   'Color': 'Blue',
#   'Brand': 'Colgate',
#   'Price': 40,
#   'Weight': 50,
#   'Quantity': 100},
#  '21': {'Name': 'Toothpaste',
#   'Color': 'White',
#   'Brand': 'Colgate',
#   'Price': 50,
#   'Weight': 10,
#   'Quantity': 100},
#  '22': {'Name': 'Shirt',
#   'Color': 'Orange',
#   'Brand': 'Nike',
#   'Price': 50,
#   'Weight': 40,
#   'Quantity': 100},
#  '23': {'Name': 'Soap',
#   'Color': 'Yellow',
#   'Brand': 'Cool',
#   'Price': 20,
#   'Weight': 50,
#   'Quantity': 100},
#  '24': {'Name': 'T-Shirt',
#   'Color': 'Blue',
#   'Brand': 'Nike',
#   'Price': 10,
#   'Weight': 10,
#   'Quantity': 100},
#  '25': {'Name': 'Jean',
#   'Color': 'Blue',
#   'Brand': 'Adidas',
#   'Price': 40,
#   'Weight': 80,
#   'Quantity': 100},
#  '26': {'Name': 'Trouser',
#   'Color': 'Grey',
#   'Brand': 'Nile',
#   'Price': 20,
#   'Weight': 50,
#   'Quantity': 100},
#  '27': {'Name': 'Shoe',
#   'Color': 'Black',
#   'Brand': 'West',
#   'Price': 20,
#   'Weight': 90,
#   'Quantity': 100},
#  '28': {'Name': 'Belt',
#   'Color': 'Black',
#   'Brand': 'Gucci',
#   'Price': 40,
#   'Weight': 40,
#   'Quantity': 100},
#  '29': {'Name': 'Running Shoe',
#   'Color': 'Brown',
#   'Brand': 'Nike',
#   'Price': 60,
#   'Weight': 50,
#   'Quantity': 100},
#  '30': {'Name': 'Repellent',
#   'Color': 'Violet',
#   'Brand': 'Dark',
#   'Price': 30,
#   'Weight': 30,
#   'Quantity': 100}}

# %% [markdown]
# # Adding new Products to the JSON file

# %%
prod_id = str(input("Enter Product ID:"))
name = str(input("Enter Product Name:"))
col = str(input("Enter Color:"))
br = str(input("Enter Brand:"))
pr = int(input("Enter Price:"))
we = int(input("Enter Weight:"))
qn = int(input("Enter Quantity:"))


record[prod_id] = {'Name': name, 'Color': col, 'Brand': br, 'Price': pr, 'Weight': we}

js = json.dumps(record)

fd = open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter Product ID:31
# Enter Product Name:Mobile
# Enter Color:Black
# Enter Brand:Vivo
# Enter Price:500
# Enter Weight:200
# Enter Quantity:100

# %%
record
# Out:
# {'1': {'Name': 'Ghee',
#   'Color': 'Yellow',
#   'Brand': 'Diary',
#   'Price': 50,
#   'Weight': 100,
#   'Quantity': 100},
#  '2': {'Name': 'Wheat',
#   'Color': 'White',
#   'Brand': 'Asarvad',
#   'Price': 67,
#   'Weight': 200,
#   'Quantity': 100},
#  '3': {'Name': 'Rice',
#   'Color': 'White',
#   'Brand': 'Fast',
#   'Price': 120,
#   'Weight': 230,
#   'Quantity': 100},
#  '4': {'Name': 'Biscuit',
#   'Color': 'Brown',
#   'Brand': 'Britania',
#   'Price': 20,
#   'Weight': 230,
#   'Quantity': 100},
#  '5': {'Name': 'Milk',
#   'Color': 'White',
#   'Brand': 'Diary',
#   'Price': 25,
#   'Weight': 10,
#   'Quantity': 100},
#  '6': {'Name': 'Egg',
#   'Color': 'White',
#   'Brand': 'Grow',
#   'Price': 15,
#   'Weight': 230,
#   'Quantity': 100},
#  '7': {'Name': 'Chocolate',
#   'Color': 'Black',
#   'Brand': 'Dairy',
#   'Price': 235,
#   'Weight': 230,
#   'Quantity': 100},
#  '8': {'Name': 'Drink',
#   'Color': 'Green',
#   'Brand': 'Pepsi',
#   'Price': 200,
#   'Weight': 230,
#   'Quantity': 100},
#  '9': {'Name': 'Jaggery',
#   'Color': 'Brown',
#   'Brand': 'Sweet',
#   'Price': 50,
#   'Weight': 20,
#   'Quantity': 100},
#  '10': {'Name': 'Salt',
#   'Color': 'White',
#   'Brand': 'Indian',
#   'Price': 20,
#   'Weight': 20,
#   'Quantity': 100},
#  '11': {'Name': 'Sugar',
#   'Color': 'White',
#   'Brand': 'Indian',
#   'Price': 10,
#   'Weight': 20,
#   'Quantity': 100},
#  '12': {'Name': 'Noodles',
#   'Color': 'White',
#   'Brand': 'Dragon',
#   'Price': 30,
#   'Weight': 20,
#   'Quantity': 100},
#  '13': {'Name': 'Jam',
#   'Color': 'Red',
#   'Brand': 'Kissan',
#   'Price': 50,
#   'Weight': 60,
#   'Quantity': 100},
#  '14': {'Name': 'Honey',
#   'Color': 'Red',
#   'Brand': 'Kissan',
#   'Price': 10,
#   'Weight': 10,
#   'Quantity': 100},
#  '15': {'Name': 'Tea',
#   'Color': 'Brown',
#   'Brand': 'Kashmir',
#   'Price': 20,
#   'Weight': 50,
#   'Quantity': 100},
#  '16': {'Name': 'Coffee',
#   'Color': 'Brown',
#   'Brand': 'Kashmir',
#   'Price': 20,
#   'Weight': 50,
#   'Quantity': 100},
#  '17': {'Name': 'Ketchup',
#   'Color': 'Red',
#   'Brand': 'Red',
#   'Price': 10,
#   'Weight': 40,
#   'Quantity': 100},
#  '18': {'Name': 'Pickle',
#   'Color': 'Red',
#   'Brand': 'Red',
#   'Price': 50,
#   'Weight': 30,
#   'Quantity': 100},
#  '19': {'Name': 'Shampoo',
#   'Color': 'Blue',
#   'Brand': 'Honey',
#   'Price': 60,
#   'Weight': 40,
#   'Quantity': 100},
#  '20': {'Name': 'Brush',
#   'Color': 'Blue',
#   'Brand': 'Colgate',
#   'Price': 40,
#   'Weight': 50,
#   'Quantity': 100},
#  '21': {'Name': 'Toothpaste',
#   'Color': 'White',
#   'Brand': 'Colgate',
#   'Price': 50,
#   'Weight': 10,
#   'Quantity': 100},
#  '22': {'Name': 'Shirt',
#   'Color': 'Orange',
#   'Brand': 'Nike',
#   'Price': 50,
#   'Weight': 40,
#   'Quantity': 100},
#  '23': {'Name': 'Soap',
#   'Color': 'Yellow',
#   'Brand': 'Cool',
#   'Price': 20,
#   'Weight': 50,
#   'Quantity': 100},
#  '24': {'Name': 'T-Shirt',
#   'Color': 'Blue',
#   'Brand': 'Nike',
#   'Price': 10,
#   'Weight': 10,
#   'Quantity': 100},
#  '25': {'Name': 'Jean',
#   'Color': 'Blue',
#   'Brand': 'Adidas',
#   'Price': 40,
#   'Weight': 80,
#   'Quantity': 100},
#  '26': {'Name': 'Trouser',
#   'Color': 'Grey',
#   'Brand': 'Nile',
#   'Price': 20,
#   'Weight': 50,
#   'Quantity': 100},
#  '27': {'Name': 'Shoe',
#   'Color': 'Black',
#   'Brand': 'West',
#   'Price': 20,
#   'Weight': 90,
#   'Quantity': 100},
#  '28': {'Name': 'Belt',
#   'Color': 'Black',
#   'Brand': 'Gucci',
#   'Price': 40,
#   'Weight': 40,
#   'Quantity': 100},
#  '29': {'Name': 'Running Shoe',
#   'Color': 'Brown',
#   'Brand': 'Nike',
#   'Price': 60,
#   'Weight': 50,
#   'Quantity': 100},
#  '30': {'Name': 'Repellent',
#   'Color': 'Violet',
#   'Brand': 'Dark',
#   'Price': 30,
#   'Weight': 30,
#   'Quantity': 100},
#  '31': {'Name': 'Mobile',
#   'Color': 'Black',
#   'Brand': 'Vivo',
#   'Price': 500,
#   'Weight': 200}}

# %%
del record['31']

# %%
record
# Out:
# {'1': {'Name': 'Ghee',
#   'Color': 'Yellow',
#   'Brand': 'Diary',
#   'Price': 50,
#   'Weight': 100,
#   'Quantity': 100},
#  '2': {'Name': 'Wheat',
#   'Color': 'White',
#   'Brand': 'Asarvad',
#   'Price': 67,
#   'Weight': 200,
#   'Quantity': 100},
#  '3': {'Name': 'Rice',
#   'Color': 'White',
#   'Brand': 'Fast',
#   'Price': 120,
#   'Weight': 230,
#   'Quantity': 100},
#  '4': {'Name': 'Biscuit',
#   'Color': 'Brown',
#   'Brand': 'Britania',
#   'Price': 20,
#   'Weight': 230,
#   'Quantity': 100},
#  '5': {'Name': 'Milk',
#   'Color': 'White',
#   'Brand': 'Diary',
#   'Price': 25,
#   'Weight': 10,
#   'Quantity': 100},
#  '6': {'Name': 'Egg',
#   'Color': 'White',
#   'Brand': 'Grow',
#   'Price': 15,
#   'Weight': 230,
#   'Quantity': 100},
#  '7': {'Name': 'Chocolate',
#   'Color': 'Black',
#   'Brand': 'Dairy',
#   'Price': 235,
#   'Weight': 230,
#   'Quantity': 100},
#  '8': {'Name': 'Drink',
#   'Color': 'Green',
#   'Brand': 'Pepsi',
#   'Price': 200,
#   'Weight': 230,
#   'Quantity': 100},
#  '9': {'Name': 'Jaggery',
#   'Color': 'Brown',
#   'Brand': 'Sweet',
#   'Price': 50,
#   'Weight': 20,
#   'Quantity': 100},
#  '10': {'Name': 'Salt',
#   'Color': 'White',
#   'Brand': 'Indian',
#   'Price': 20,
#   'Weight': 20,
#   'Quantity': 100},
#  '11': {'Name': 'Sugar',
#   'Color': 'White',
#   'Brand': 'Indian',
#   'Price': 10,
#   'Weight': 20,
#   'Quantity': 100},
#  '12': {'Name': 'Noodles',
#   'Color': 'White',
#   'Brand': 'Dragon',
#   'Price': 30,
#   'Weight': 20,
#   'Quantity': 100},
#  '13': {'Name': 'Jam',
#   'Color': 'Red',
#   'Brand': 'Kissan',
#   'Price': 50,
#   'Weight': 60,
#   'Quantity': 100},
#  '14': {'Name': 'Honey',
#   'Color': 'Red',
#   'Brand': 'Kissan',
#   'Price': 10,
#   'Weight': 10,
#   'Quantity': 100},
#  '15': {'Name': 'Tea',
#   'Color': 'Brown',
#   'Brand': 'Kashmir',
#   'Price': 20,
#   'Weight': 50,
#   'Quantity': 100},
#  '16': {'Name': 'Coffee',
#   'Color': 'Brown',
#   'Brand': 'Kashmir',
#   'Price': 20,
#   'Weight': 50,
#   'Quantity': 100},
#  '17': {'Name': 'Ketchup',
#   'Color': 'Red',
#   'Brand': 'Red',
#   'Price': 10,
#   'Weight': 40,
#   'Quantity': 100},
#  '18': {'Name': 'Pickle',
#   'Color': 'Red',
#   'Brand': 'Red',
#   'Price': 50,
#   'Weight': 30,
#   'Quantity': 100},
#  '19': {'Name': 'Shampoo',
#   'Color': 'Blue',
#   'Brand': 'Honey',
#   'Price': 60,
#   'Weight': 40,
#   'Quantity': 100},
#  '20': {'Name': 'Brush',
#   'Color': 'Blue',
#   'Brand': 'Colgate',
#   'Price': 40,
#   'Weight': 50,
#   'Quantity': 100},
#  '21': {'Name': 'Toothpaste',
#   'Color': 'White',
#   'Brand': 'Colgate',
#   'Price': 50,
#   'Weight': 10,
#   'Quantity': 100},
#  '22': {'Name': 'Shirt',
#   'Color': 'Orange',
#   'Brand': 'Nike',
#   'Price': 50,
#   'Weight': 40,
#   'Quantity': 100},
#  '23': {'Name': 'Soap',
#   'Color': 'Yellow',
#   'Brand': 'Cool',
#   'Price': 20,
#   'Weight': 50,
#   'Quantity': 100},
#  '24': {'Name': 'T-Shirt',
#   'Color': 'Blue',
#   'Brand': 'Nike',
#   'Price': 10,
#   'Weight': 10,
#   'Quantity': 100},
#  '25': {'Name': 'Jean',
#   'Color': 'Blue',
#   'Brand': 'Adidas',
#   'Price': 40,
#   'Weight': 80,
#   'Quantity': 100},
#  '26': {'Name': 'Trouser',
#   'Color': 'Grey',
#   'Brand': 'Nile',
#   'Price': 20,
#   'Weight': 50,
#   'Quantity': 100},
#  '27': {'Name': 'Shoe',
#   'Color': 'Black',
#   'Brand': 'West',
#   'Price': 20,
#   'Weight': 90,
#   'Quantity': 100},
#  '28': {'Name': 'Belt',
#   'Color': 'Black',
#   'Brand': 'Gucci',
#   'Price': 40,
#   'Weight': 40,
#   'Quantity': 100},
#  '29': {'Name': 'Running Shoe',
#   'Color': 'Brown',
#   'Brand': 'Nike',
#   'Price': 60,
#   'Weight': 50,
#   'Quantity': 100},
#  '30': {'Name': 'Repellent',
#   'Color': 'Violet',
#   'Brand': 'Dark',
#   'Price': 30,
#   'Weight': 30,
#   'Quantity': 100}}
